# %%
import pandas as pd

df = pd.read_csv('data_csv.csv')

print(df.to_string())
# Out:
#           Date   CustomerName     Product  TotalAmount
# 0   2025-08-01    Alice Kumar      Laptop        75000
# 1   2025-08-01     Ravi Singh       Mouse         1000
# 2   2025-08-02       Neha Rao    Keyboard         1500
# 3   2025-08-02    John Dsouza     Monitor        12000
# 4   2025-08-03     Meena Jain      Laptop       148000
# 5   2025-08-03    Arjun Patil  Headphones         6000
# 6   2025-08-04    Sneha Reddy       Mouse          500
# 7   2025-08-04   Deepak Verma    Keyboard         3000
# 8   2025-08-05   Anjali Mehta      Laptop        76000
# 9   2025-08-05    Kiran Joshi     Monitor        23000
# 10  2025-08-06     Farhan Ali       Mouse         2000
# 11  2025-08-06     Pooja Nair  Headphones         4000
# 12  2025-08-07   Manoj Shetty    Keyboard         1500
# 13  2025-08-07   Divya Sharma      Laptop        75500
# 14  2025-08-08  Ajay Kulkarni     Monitor        11800
# 15  2025-08-08     Rekha Iyer       Mouse         1500
# 16  2025-08-09   Harish Menon    Keyboard         3000
# 17  2025-08-09     Shweta Rao      Laptop        76500
# 18  2025-08-10    Nikhil Jain  Headphones         2000
# 19  2025-08-10   Preeti Desai     Monitor        23800
# 20  2025-08-11  Sachin Pillai       Mouse          500
# 21  2025-08-11     Anita Bhat    Keyboard         4500
# 22  2025-08-12    Varun Gupta      Laptop       154000
# 23  2025-08-12     Geeta Rani  Headphones         4000
# 24  2025-08-13      Rohan Das     Monitor        11700

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data_csv.csv')  
product_sales = df.groupby('Product')['TotalAmount'].sum().reset_index()
print(product_sales)
# Out:
#       Product  TotalAmount
# 0  Headphones        16000
# 1    Keyboard        13500
# 2      Laptop       605000
# 3     Monitor        82300
# 4       Mouse         5500

# %%
plt.figure(figsize=(8, 5))
plt.bar(product_sales['Product'], product_sales['TotalAmount'], color='skyblue')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Amount (₹)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
